# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from pandapower.tdpf.create_jacobian_tdpf import calc_a0_a1_a2_tau, calc_t_ss

# %%
# conductor data
t_amb = 40
t_max = 90
r_ref_ohm_per_m = 0.1824e-3
conductor_outer_diameter_m = 18.2e-3
v_m_per_s = 0.5
wind_angle_degree = 45
s_w_per_square_meter = 1000
alpha = 0.004
gamma = epsilon = 0.5
mc_joule_per_m_k = 525

# %% [markdown]
# # Wind speed

# %%
v_m_per_s = 0.5
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_05 = [calc_t_ss(i, a0, a1, a2) for i in range(601)]

# %%
v_m_per_s = 2
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_2 = [calc_t_ss(i, a0, a1, a2) for i in range(601)]

# %%
v_m_per_s = 5
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_5 = [calc_t_ss(i, a0, a1, a2) for i in range(601)]

# %%
ax=plt.subplot()
ax.plot(np.vstack([t_05, t_2, t_5]).T)
ax.grid(True)

# %% [markdown]
# # Ambient temperature

# %%
v_m_per_s = 0.5
t_amb = 0
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_0 = [calc_t_ss(i, a0, a1, a2) for i in range(601)]

# %%
t_amb = 20
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_20 = [calc_t_ss(i, a0, a1, a2) for i in range(601)]

# %%
t_amb = 40
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_40 = [calc_t_ss(i, a0, a1, a2) for i in range(601)]

# %%
ax=plt.subplot()
ax.plot(np.vstack([t_0, t_20, t_40]).T)
ax.grid(True)

# %% [markdown]
# # Wind Direction

# %%
v_m_per_s = 0.5
wind_angle_degree = 0
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_0 = [calc_t_ss(i, a0, a1, a2) for i in range(601)]

# %%
wind_angle_degree = 45
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_45 = [calc_t_ss(i, a0, a1, a2) for i in range(601)]

# %%
wind_angle_degree = 90
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)


t_90 = [calc_t_ss(i, a0, a1, a2) for i in range(601)]

# %%
ax=plt.subplot()
ax.plot(np.vstack([t_0, t_45, t_90]).T)
ax.grid(True)

# %% [markdown]
# # Solar Radiation

# %%
v_m_per_s = 0.5
wind_angle_degree = 45
s_w_per_square_meter = 0
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_0 = [calc_t_ss(i, a0, a1, a2) for i in range(601)]

# %%
s_w_per_square_meter = 500
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_500 = [calc_t_ss(i, a0, a1, a2) for i in range(601)]

# %%
s_w_per_square_meter = 1000
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)


t_1000 = [calc_t_ss(i, a0, a1, a2) for i in range(601)]

# %%
ax=plt.subplot()
ax.plot(np.vstack([t_0, t_500, t_1000]).T)
ax.grid(True)

# %%
# conductor data 2
t_amb = 40
t_max = 150
r_ref_ohm_per_m = 0.0373e-3
conductor_outer_diameter_m = 38.4e-3
v_m_per_s = 0.5
wind_angle_degree = 45
s_w_per_square_meter = 1000
alpha = 0.0036
gamma = epsilon = 0.5
mc_joule_per_m_k = 2185
max_current = 2501

# %% [markdown]
# # Wind speed

# %%
v_m_per_s = 0.5
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_05 = [calc_t_ss(i, a0, a1, a2) for i in range(max_current)]

# %%
v_m_per_s = 2
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_2 = [calc_t_ss(i, a0, a1, a2) for i in range(max_current)]

# %%
v_m_per_s = 5
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_5 = [calc_t_ss(i, a0, a1, a2) for i in range(max_current)]

# %%
ax=plt.subplot()
ax.plot(np.vstack([t_05, t_2, t_5]).T)
ax.grid(True)

# %% [markdown]
# # Ambient temperature

# %%
v_m_per_s = 0.5
t_amb = 0
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_0 = [calc_t_ss(i, a0, a1, a2) for i in range(max_current )]

# %%
t_amb = 20
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_20 = [calc_t_ss(i, a0, a1, a2) for i in range(max_current )]

# %%
t_amb = 40
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_40 = [calc_t_ss(i, a0, a1, a2) for i in range(max_current )]

# %%
ax=plt.subplot()
ax.plot(np.vstack([t_0, t_20, t_40]).T)
ax.grid(True)

# %% [markdown]
# # Wind Direction

# %%
v_m_per_s = 0.5
wind_angle_degree = 0
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_0 = [calc_t_ss(i, a0, a1, a2) for i in range(max_current )]

# %%
wind_angle_degree = 45
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_45 = [calc_t_ss(i, a0, a1, a2) for i in range(max_current )]

# %%
wind_angle_degree = 90
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)


t_90 = [calc_t_ss(i, a0, a1, a2) for i in range(max_current )]

# %%
ax=plt.subplot()
ax.plot(np.vstack([t_0, t_45, t_90]).T)
ax.grid(True)

# %% [markdown]
# # Solar Radiation

# %%
v_m_per_s = 0.5
wind_angle_degree = 45
s_w_per_square_meter = 0
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_0 = [calc_t_ss(i, a0, a1, a2) for i in range(max_current )]

# %%
v_m_per_s = 0.5
wind_angle_degree = 45
s_w_per_square_meter = 500
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)

t_500 = [calc_t_ss(i, a0, a1, a2) for i in range(max_current )]

# %%
v_m_per_s = 0.5
wind_angle_degree = 45
s_w_per_square_meter = 1000
a0, a1, a2, tau = calc_a0_a1_a2_tau(t_amb=t_amb, t_max=t_max, r_ref_ohm_per_m=r_ref_ohm_per_m,
                                    conductor_outer_diameter_m=conductor_outer_diameter_m, mc_joule_per_m_k=mc_joule_per_m_k,
                                    v_m_per_s=v_m_per_s, wind_angle_degree=wind_angle_degree, s_w_per_square_meter=s_w_per_square_meter)


t_1000 = [calc_t_ss(i, a0, a1, a2) for i in range(max_current )]

# %%
ax=plt.subplot()
ax.plot(np.vstack([t_0, t_500, t_1000]).T)
ax.grid(True)
