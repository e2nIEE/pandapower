# %% [markdown]
# # Using power-grid-model for calculations
# power-grid-model is a Python library for steady-state distribution power system analysis. The core of the library is written in C++. Using it for calculation can give a significant boost to performance, especially for asymmetric calculations.
#
# Currently power-grid-model supports limited components hence some of components or features are not supported. You can find the complete details about them [here](https://power-grid-model-io.readthedocs.io/en/stable/converters/pandapower_converter.html). An exception will be raised for them.
# ## Power flow calculation
# First imports and initialize a basic network

# %%
from pandapower.run import runpp_pgm
from pandapower.networks import example_simple
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
net = example_simple()
# Remove Generator since its not supported yet
net["gen"] = net["gen"].iloc[:0]

# Remove line geodata column as pd.NA cannot be handled by power_grid_models
net.line = net.line.drop(columns=["geo"])
net.shunt = net.shunt.drop(columns=["id_characteristic_table"])

# %% [markdown]
# A powerflow can be run using power-grid-model for calculation by using the `pp.runpp_pgm` function. The function has its own arguments different from `pp.runpp()`

# %%
runpp_pgm(net)
net.res_bus
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 runpp_pgm(net)
#       2 net.res_bus
#
# File ~/pandapower/pandapower/run.py:289, in runpp_pgm(net, algorithm, max_iterations, error_tolerance_vm_pu, symmetric, validate_input)
#     286 # 2. Convert the pandapower data to the power grid model format. Ignoring the 'extra info', which is a
#     287 #    dictionary representation of the internal state of the PandaPowerConverter.
#     288 pgm_converter = PandaPowerConverter()
# --> 289 pgm_input_data, _extra_info = pgm_converter.load_input_data(net, make_extra_info=False)
#     291 # 3. If required, validate the input data
#     292 if validate_input:
#
# File ~/.conda/envs/pandapower314/lib/python3.14/site-packages/power_grid_model_io/converters/base_converter.py:53, in BaseConverter.load_input_data(self, data, make_extra_info)
#      51 data = self._load_data(data)
#      52 extra_info: ExtraInfo = {}
# ---> 53 parsed_data = self._parse_data(
#      54     data=data, data_type=DatasetType.input, extra_info=extra_info if make_extra_info else None
#      55 )
#      56 if isinstance(parsed_data, list):
#      57     raise TypeError("Input data can not be batch data")
#
# File ~/.conda/envs/pandapower314/lib/python3.14/site-packages/power_grid_model_io/converters/pandapower_converter.py:124, in PandaPowerConverter._parse_data(self, data, data_type, extra_info)
#     122 # Convert
#     123 if data_type == DatasetType.input:
# --> 124     self._create_input_data()
#     125 else:
#     126     raise ValueError(f"Data type: '{data_type}' is not implemented")
#
# File ~/.conda/envs/pandapower314/lib/python3.14/site-packages/power_grid_model_io/converters/pandapower_converter.py:185, in PandaPowerConverter._create_input_data(self)
#     183 self._create_pgm_input_lines()
#     184 self._create_pgm_input_sources()
# --> 185 self._create_pgm_input_sym_loads()
#     186 self._create_pgm_input_shunts()
#     187 self._create_pgm_input_transformers()
#
# File ~/.conda/envs/pandapower314/lib/python3.14/site-packages/power_grid_model_io/converters/pandapower_converter.py:661, in PandaPowerConverter._create_pgm_input_sym_loads(self)
#     658 if ComponentType.sym_load in self.pgm_input_data:
#     659     raise ValueError("Symmetrical Load component already exists in pgm_input_data")
# --> 661 if np.any(self._get_pp_attr("load", "type", expected_type="O", default=None) == "delta"):
#     662     raise NotImplementedError("Delta loads are not implemented, only wye loads are supported in PGM.")
#     664 scaling = self._get_pp_attr("load", "scaling", expected_type="f8", default=1.0)
#
# File ~/.conda/envs/pandapower314/lib/python3.14/site-packages/power_grid_model_io/converters/pandapower_converter.py:2641, in PandaPowerConverter._get_pp_attr(self, table, attribute, expected_type, default)
#    2638 attr_data = pp_component_data[attribute]
#    2640 # If any of the attribute values are missing, and a default is supplied, fill the nans with the default value
# -> 2641 nan_values = np.equal(attr_data, None) if attr_data.dtype is np.dtype("O") else np.isnan(attr_data)  # type: ignore
#    2643 if any(nan_values):
#    2644     attr_data = attr_data.fillna(value=default, inplace=False)
#
# File ~/.conda/envs/pandapower314/lib/python3.14/site-packages/pandas/core/generic.py:2193, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2189 @final
#    2190 def __array_ufunc__(
#    2191     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2192 ):
# -> 2193     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File ~/.conda/envs/pandapower314/lib/python3.14/site-packages/pandas/core/arraylike.py:399, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     396 elif self.ndim == 1:
#     397     # ufunc(series, ...)
#     398     inputs = tuple(extract_array(x, extract_numpy=True) for x in inputs)
# --> 399     result = getattr(ufunc, method)(*inputs, **kwargs)
#     400 else:
#     401     # ufunc(dataframe)
#     402     if method == "__call__" and not kwargs:
#     403         # for np.<ufunc>(..) calls
#     404         # kwargs cannot necessarily be handled block-by-block, so only
#     405         # take this path if there are no kwargs
#
# File ~/.conda/envs/pandapower314/lib/python3.14/site-packages/pandas/core/arrays/numpy_.py:196, in NumpyExtensionArray.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#     192 if out:
#     193     kwargs["out"] = tuple(
#     194         x._ndarray if isinstance(x, NumpyExtensionArray) else x for x in out
#     195     )
# --> 196 result = getattr(ufunc, method)(*inputs, **kwargs)
#     198 if ufunc.nout > 1:
#     199     # multiple return values; re-box array-like results
#     200     return tuple(type(self)(x) for x in result)
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %% [markdown]
# To know more about the library, refer to [power-grid-model](https://github.com/alliander-opensource/power-grid-model) and repository and [power-grid-model documentation](https://power-grid-model.readthedocs.io/en/stable/). The conversion from pandapower net to and from power-grid-model is handled by [power-grid-model-io](https://github.com/alliander-opensource/power-grid-model-io) ([power-grid-model-io documentation](https://power-grid-model-io.readthedocs.io/en/stable/)).
#
# The user however would usually not have to concern with these as power-grid-model is integrated into pandapower powerflow functions directly.
