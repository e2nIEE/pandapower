# %%
import numpy as np
from pandapower.plotting import simple_plot
from pandapower.test.shortcircuit.test_1ph import vde_232

# %% [markdown]
# Create example net from IEC 60909:4-2021 Figure 5

# %%
net = vde_232()
vn_trafo_hv = net.trafo.vn_hv_kv
vn_trafo_lv = net.trafo.vn_lv_kv
sn_mva = net.trafo.sn_mva
vk0_percent = net.trafo.vk0_percent
vkr0_percent = net.trafo.vkr0_percent

# %%
simple_plot(net, plot_gens=True, gen_size=0.05, trafo_size=10, ext_grid_size=5, draw_by_type=False);
# Out:
# No or insufficient geodata available --> Creating artificial coordinates. This may take some time
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'NoneType' object has no attribute 'cos'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 simple_plot(net, plot_gens=True, gen_size=0.05, trafo_size=10, ext_grid_size=5, draw_by_type=False);
#
# File ~/pandapower/pandapower/plotting/simple_plot.py:959, in simple_plot(net, respect_switches, line_width, bus_size, ext_grid_size, trafo_size, plot_loads, plot_gens, plot_sgens, orientation, load_size, gen_size, sgen_size, switch_size, switch_distance, plot_line_switches, plot_bus_switches, scale_size, bus_color, line_color, dcline_color, trafo_color, ext_grid_color, switch_color, library, show_plot, ax, draw_by_type, bus_dc_size, bus_dc_color, line_dc_color, vsc_size, vsc_color, highlight_buses, highlight_lines, enable_hover, highlight_bus_size_factor, highlight_line_width_factor, highlight_color, colormap_type, line_limits, bus_limits, cmap_lines, cmap_buses, plot_colorbars)
#     956     collections.append(sgc)
#     958 if plot_gens and len(net.gen):
# --> 959     gc = create_gen_collection(
#     960         net, size=gen_size, orientation=orientation,
#     961         unique_angles=angles, draw_by_type=draw_by_type,
#     962     )
#     963     collections.append(gc)
#     965 if plot_loads and len(net.load):
#     966     # separate variable name to prevent rebinding normal_lc / cmap_lc
#
# File ~/pandapower/pandapower/plotting/collections.py:1218, in create_gen_collection(net, gens, size, infofunc, orientation, picker, patch_type, unique_angles, draw_by_type, **kwargs)
#    1186 def create_gen_collection(
#    1187         net: pandapowerNet,
#    1188         gens=None,
#    (...)   1195         draw_by_type: bool = False,
#    1196         **kwargs):
#    1197     """
#    1198     Creates a matplotlib patch collection of pandapower gens.
#    1199
#    (...)   1216         patch collection, line collection
#    1217     """
# -> 1218     return _create_gen_or_sgen_collection(
#    1219         net, gens, size, infofunc, orientation, picker, patch_type, unique_angles, draw_by_type, "gen", **kwargs
#    1220     )
#
# File ~/pandapower/pandapower/plotting/collections.py:1172, in _create_gen_or_sgen_collection(net, indices, size, infofunc, orientation, picker, patch_type, unique_angles, draw_by_type, attribute, **kwargs)
#    1169     angles = orientation
#    1171 color = kwargs.pop("color", "k")
# -> 1172 return _create_node_element_collection(
#    1173     node_coords=node_coords,
#    1174     patch_maker=sgen_patches if attribute == "sgen" else gen_patches,
#    1175     size=size,
#    1176     infos=infos,
#    1177     orientation=angles,
#    1178     picker=picker,
#    1179     line_color=color,
#    1180     patch_type=patch_type,
#    1181     draw_by_type=draw_by_type,
#    1182     **kwargs
#    1183 )
#
# File ~/pandapower/pandapower/plotting/collections.py:318, in _create_node_element_collection(node_coords, patch_maker, size, infos, repeat_infos, orientation, picker, patch_facecolor, patch_edgecolor, line_color, patch_type, unique_angles, draw_by_type, **kwargs)
#     315 linewidths = kwargs.pop("linewidth", linewidths)
#     316 linewidths = kwargs.pop("lw", linewidths)
# --> 318 lines, polys, popped_keywords = patch_maker(
#     319     node_coords=node_coords,
#     320     size=size,
#     321     angles=angles,
#     322     patch_type=patch_type,
#     323     unique_angles=unique_angles,
#     324     draw_by_type=draw_by_type,
#     325     patch_facecolor=patch_facecolor,
#     326     patch_edgecolor=patch_edgecolor,
#     327     **kwargs
#     328 )
#     329 for kw in set(popped_keywords) & set(kwargs.keys()):
#     330     kwargs.pop(kw)
#
# File ~/pandapower/pandapower/plotting/patch_makers.py:401, in gen_patches(node_coords, size, angles, patch_type, draw_by_type, **kwargs)
#     399 if draw_by_type:
#     400     pass  # TODO: add support for other patch types
# --> 401 p2 = node_geo + _rotate_dim2(np.array([0, size + offset]), _angle)
#     402 circ_edge = node_geo + _rotate_dim2(np.array([0, offset]), _angle)
#     403 polys.append(Circle(p2, size, fc=facecolors[i], ec=edgecolors[i]))
#
# File ~/pandapower/pandapower/plotting/plotting_toolbox.py:24, in _rotate_dim2(arr, ang)
#      15 def _rotate_dim2(arr, ang):
#      16     """
#      17     Rotate the input vector with the given angle.
#      18
#    (...)     22     :type ang: float
#      23     """
# ---> 24     return np.dot(np.array([[np.cos(ang), np.sin(ang)], [-np.sin(ang), np.cos(ang)]]), arr)
#
# TypeError: loop of ufunc does not support argument 0 of type NoneType which has no callable cos method

# %% [markdown]
# Calculate the zero-sequence impedance of the power station unit transformer related to the HV side (without correction factor $K_T$)
#
# $\underline{Z}_{(0)THV} = (\frac{u_{Rr}}{100 \%} + j \frac{u_{Xr}}{100 \%}) \frac{U_{rTHV}^2}{S_{rT}}$:

# %%
vkx0_percent = np.sqrt(np.square(vk0_percent) - np.square(vkr0_percent))
z_0THV = (vkr0_percent / 100 + 1j * vkx0_percent / 100) * (np.square(vn_trafo_hv) / sn_mva)
z_0THV.at[0]

# %% [markdown]
# Calculate the correction factor for the power system unit with OLTC
#
# $K_S = \frac{U_{nQ}^2}{U_{rG}^2} \cdot \frac{U_{rTLV}^2}{U_{rTHV}^2} \cdot \frac{c_{max}}{1+|x_d^{''} - x_T| \sqrt{1-cos^2_{\phi rG}}}$:

# %%
v_g = net.gen.vn_kv
v_q = net.bus.loc[net.trafo["hv_bus"].values, "vn_kv"].values
ps_cmax = 1.1
x_t = net.trafo["vk_percent"].values / 100
xdss_pu = net.gen.xdss_pu
sin_phi_gen = np.sqrt(np.clip(1 - net.gen.cos_phi.values**2, 0, None))

ks = (v_q**2/v_g**2) * (vn_trafo_lv**2/vn_trafo_hv**2) * ps_cmax / (1 + np.abs(xdss_pu - x_t) * sin_phi_gen)

# %%
ks.at[0]

# %% [markdown]
# Calculate the corrected zero-sequence impedance for the power system unit with OLTC
#
# $\underline{Z}_{(0)SK} = K_S \cdot \underline{Z}_{(0)THV} + 3 \cdot \underline{Z}_N$:

# %%
zn = 1j * net.trafo.xn_ohm
z_0SK = ks * z_0THV + 3*zn
z_0SK.at[0]

# %% [markdown]
# Calculate the correction factor for the power system unit without OLTC
#
# $K_{SO} = \frac{U_{nQ}}{U_{rG} \cdot (1+p_G)} \cdot \frac{U_{rTLV}}{U_{rTHV}} \cdot (1 \pm p_T) \cdot \frac{c_{max}}{1+x_d^{''} \sqrt{1-cos^2_{\phi rG}}}$:

# %%
p_g = net.gen.pg_percent / 100
p_t = net.trafo['pt_percent'] / 100
kso = (v_q / (v_g * (1 + p_g))) * (vn_trafo_lv / vn_trafo_hv) * (1 - p_t) * ps_cmax / (1 + xdss_pu * sin_phi_gen)

# %% [markdown]
# Calculate the corrected zero-sequence impedance for the power system unit without OLTC
#
# $\underline{Z}_{(0)SOK} = K_{SO} \cdot \underline{Z}_{(0)THV} + 3 \cdot \underline{Z}_N$:

# %%
z_0SOK = kso * z_0THV + 3*zn
z_0SOK.at[0]
