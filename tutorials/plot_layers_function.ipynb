# %%
import pandas as pd
import pandapower.networks as nw
from pandapower.plotting.plotly.layers_plotly import layers_plotly

# %%
net = nw.mv_oberrhein("generation")

cluster_bus = pd.read_excel("bus_groups_5.xlsx", engine = 'openpyxl', index_col = 0)
cluster_bus = cluster_bus.drop(["bus*"], axis = 1)

layers_plotly(net, cluster_bus)
